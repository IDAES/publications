# %%
import os

from util.surrogate import SurrogateProcessModels
from util.data import get_model_data, DataObject
import pandas as pd
import numpy as np

from util.solve import (
    print_summary,
    lmp_hist,
)

import scipy
import matplotlib.pyplot as plt

# %%
data = DataObject()
surrogate = SurrogateProcessModels()
surrogate.generate_surrogate_models()
model_data = get_model_data()

# %%
pd.set_option('display.precision', 2)
result_dir = "../market_results_20"
groups = ["historical", "nrel", "princeton", "o3"]
models = ["model0", "model1", "model3", "model4", "model5", "model6"]

lmp_median = []
lmp_bc = []
model0_prof = []


for data_set in data.metadata:
    if data.metadata[data_set]["group"] not in groups:
        continue
    print("=========================================================================")
    print(data_set)
    print("=========================================================================")    
    lmp_hist(data.data[data_set], range=(-20, 200))

    
    lmp_median.append(data.data[data_set].median())
    g = data.data[data_set].skew()
    k = data.data[data_set].kurtosis() - 3
    n = data.data[data_set].count()
    lmp_bc.append((g**2 + 1)/(k + 3*(n-1)**2/((n-2)*(n-3))))
                  
    print(f"LMP Range ($/MWh) = ({min(data.data[data_set])}, {max(data.data[data_set])})")
    print(f"LMP Median ($/MWh) = {data.data[data_set].median():.2f}")
    print(f"LMP Mean ($/MWh) = {data.data[data_set].mean():.2f}")
    print(f"Natural Gas Price ($/million BTU) = {data.metadata[data_set]['ng_price']:.2f}")
    print(f"Bimodality Coefficient = {lmp_bc[-1]:.2f}")
    print()
    
    for h2_price in [2.0]:
        result_dir = f"../market_results_{int(h2_price*10)}"
        if h2_price == 2.0:
            models = ["model0", "model1", "model3", "model4", "model5", "model6"]
        else:
            models = ["model3", "model4", "model5", "model6"]
        print(f"H2 Price ($/kg) = {h2_price}")
        for model in models:
            result_file = os.path.join(result_dir, f"{data_set}_{model}.csv")
            df = pd.read_csv(result_file)
            n = len(df["profit ($/hr)"])
            profit = (sum(df["profit ($/hr)"]) - sum(df["start_cost"]) - sum(df["stop_cost"]))/n*365*24/1e6
# Out:
# =========================================================================
# CAISO_NP15_2019
# =========================================================================
# LMP Range ($/MWh) = (-43.3701, 1013.6738)
# LMP Median ($/MWh) = 30.84
# LMP Mean ($/MWh) = 35.59
# Natural Gas Price ($/million BTU) = 3.87
# Bimodality Coefficient = 0.68
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# CAISO_NP15_2022
# =========================================================================
# LMP Range ($/MWh) = (-16.3892, 1971.8911)
# LMP Median ($/MWh) = 65.46
# LMP Mean ($/MWh) = 72.48
# Natural Gas Price ($/million BTU) = 7.47
# Bimodality Coefficient = 0.85
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# CAISO_ZP26_2019
# =========================================================================
# LMP Range ($/MWh) = (-40.6231, 1065.9115)
# LMP Median ($/MWh) = 30.68
# LMP Mean ($/MWh) = 35.32
# Natural Gas Price ($/million BTU) = 3.87
# Bimodality Coefficient = 0.69
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# CAISO_ZP26_2022
# =========================================================================
# LMP Range ($/MWh) = (-35.0853, 1976.5301)
# LMP Median ($/MWh) = 61.25
# LMP Mean ($/MWh) = 64.98
# Natural Gas Price ($/million BTU) = 7.47
# Bimodality Coefficient = 0.82
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# CAISO_SP15_2019
# =========================================================================
# LMP Range ($/MWh) = (-36.4988, 980.3147)
# LMP Median ($/MWh) = 30.81
# LMP Mean ($/MWh) = 35.76
# Natural Gas Price ($/million BTU) = 3.87
# Bimodality Coefficient = 0.69
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# CAISO_SP15_2022
# =========================================================================
# LMP Range ($/MWh) = (-27.4744, 1994.734)
# LMP Median ($/MWh) = 61.89
# LMP Mean ($/MWh) = 68.58
# Natural Gas Price ($/million BTU) = 7.47
# Bimodality Coefficient = 0.80
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_NORTH_2019
# =========================================================================
# LMP Range ($/MWh) = (-10.4186, 4696.8861)
# LMP Median ($/MWh) = 19.12
# LMP Mean ($/MWh) = 27.53
# Natural Gas Price ($/million BTU) = 2.39
# Bimodality Coefficient = 0.87
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_NORTH_2022
# =========================================================================
# LMP Range ($/MWh) = (-464.7304, 5073.4436)
# LMP Median ($/MWh) = 46.14
# LMP Mean ($/MWh) = 56.40
# Natural Gas Price ($/million BTU) = 7.05
# Bimodality Coefficient = 0.82
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_SOUTH_2019
# =========================================================================
# LMP Range ($/MWh) = (-50.289, 4694.8095)
# LMP Median ($/MWh) = 19.59
# LMP Mean ($/MWh) = 27.57
# Natural Gas Price ($/million BTU) = 2.39
# Bimodality Coefficient = 0.87
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_SOUTH_2022
# =========================================================================
# LMP Range ($/MWh) = (-31.1793, 4680.6634)
# LMP Median ($/MWh) = 45.10
# LMP Mean ($/MWh) = 54.81
# Natural Gas Price ($/million BTU) = 7.05
# Bimodality Coefficient = 0.79
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_WEST_2019
# =========================================================================
# LMP Range ($/MWh) = (-24.6412, 4697.196)
# LMP Median ($/MWh) = 18.79
# LMP Mean ($/MWh) = 26.20
# Natural Gas Price ($/million BTU) = 2.39
# Bimodality Coefficient = 0.86
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_WEST_2022
# =========================================================================
# LMP Range ($/MWh) = (-47.6123, 5143.3014)
# LMP Median ($/MWh) = 43.88
# LMP Mean ($/MWh) = 51.22
# Natural Gas Price ($/million BTU) = 7.05
# Bimodality Coefficient = 0.81
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_HOUSTON_2019
# =========================================================================
# LMP Range ($/MWh) = (-71.9689, 4694.6368)
# LMP Median ($/MWh) = 19.63
# LMP Mean ($/MWh) = 28.20
# Natural Gas Price ($/million BTU) = 2.39
# Bimodality Coefficient = 0.86
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ERCOT_HOUSTON_2022
# =========================================================================
# LMP Range ($/MWh) = (-28.7943, 4835.4304)
# LMP Median ($/MWh) = 48.50
# LMP Mean ($/MWh) = 64.26
# Natural Gas Price ($/million BTU) = 7.05
# Bimodality Coefficient = 0.79
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ISO_NE_2019
# =========================================================================
# LMP Range ($/MWh) = (-56.16, 261.35)
# LMP Median ($/MWh) = 24.55
# LMP Mean ($/MWh) = 30.68
# Natural Gas Price ($/million BTU) = 4.50
# Bimodality Coefficient = 0.68
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# ISO_NE_2022
# =========================================================================
# LMP Range ($/MWh) = (-150.91, 764.88)
# LMP Median ($/MWh) = 65.42
# LMP Mean ($/MWh) = 81.93
# Natural Gas Price ($/million BTU) = 10.76
# Bimodality Coefficient = 0.58
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# NYISO_2019
# =========================================================================
# LMP Range ($/MWh) = (-186.74, 356.71)
# LMP Median ($/MWh) = 19.18
# LMP Mean ($/MWh) = 20.09
# Natural Gas Price ($/million BTU) = 3.05
# Bimodality Coefficient = 0.15
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# NYISO_2022
# =========================================================================
# LMP Range ($/MWh) = (-410.7, 1215.43)
# LMP Median ($/MWh) = 46.05
# LMP Mean ($/MWh) = 53.84
# Natural Gas Price ($/million BTU) = 7.57
# Bimodality Coefficient = 0.36
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MYSO_INDIANA_2019
# =========================================================================
# LMP Range ($/MWh) = (2.26, 936.4)
# LMP Median ($/MWh) = 23.33
# LMP Mean ($/MWh) = 26.41
# Natural Gas Price ($/million BTU) = 2.73
# Bimodality Coefficient = 0.66
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MYSO_INDIANA_2022
# =========================================================================
# LMP Range ($/MWh) = (-4.43, 1082.57)
# LMP Median ($/MWh) = 59.28
# LMP Mean ($/MWh) = 70.07
# Natural Gas Price ($/million BTU) = 8.04
# Bimodality Coefficient = 0.51
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MYSO_LOUISIANA_2019
# =========================================================================
# LMP Range ($/MWh) = (-31.26, 968.31)
# LMP Median ($/MWh) = 22.67
# LMP Mean ($/MWh) = 24.86
# Natural Gas Price ($/million BTU) = 2.73
# Bimodality Coefficient = 0.61
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MYSO_LOUISIANA_2022
# =========================================================================
# LMP Range ($/MWh) = (-3.03, 1102.38)
# LMP Median ($/MWh) = 53.81
# LMP Mean ($/MWh) = 62.18
# Natural Gas Price ($/million BTU) = 8.04
# Bimodality Coefficient = 0.46
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MYSO_MINNESOTA_2019
# =========================================================================
# LMP Range ($/MWh) = (-38.56, 661.22)
# LMP Median ($/MWh) = 20.19
# LMP Mean ($/MWh) = 21.97
# Natural Gas Price ($/million BTU) = 3.73
# Bimodality Coefficient = 0.65
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MYSO_MINNESOTA_2022
# =========================================================================
# LMP Range ($/MWh) = (-62.28, 1111.41)
# LMP Median ($/MWh) = 37.55
# LMP Mean ($/MWh) = 44.66
# Natural Gas Price ($/million BTU) = 8.04
# Bimodality Coefficient = 0.42
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# PJM_WEST_2019
# =========================================================================
# LMP Range ($/MWh) = (-52.9956, 746.5853)
# LMP Median ($/MWh) = 23.12
# LMP Mean ($/MWh) = 26.38
# Natural Gas Price ($/million BTU) = 2.43
# Bimodality Coefficient = 0.70
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# PJM_WEST_2022
# =========================================================================
# LMP Range ($/MWh) = (-20.2954, 2859.1057)
# LMP Median ($/MWh) = 58.76
# LMP Mean ($/MWh) = 70.66
# Natural Gas Price ($/million BTU) = 7.04
# Bimodality Coefficient = 0.52
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# SPP_NORTH_2019
# =========================================================================
# LMP Range ($/MWh) = (-46.4777, 1130.7242)
# LMP Median ($/MWh) = 16.91
# LMP Mean ($/MWh) = 20.19
# Natural Gas Price ($/million BTU) = 2.75
# Bimodality Coefficient = 0.57
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# SPP_NORTH_2022
# =========================================================================
# LMP Range ($/MWh) = (-102.7981, 821.6178)
# LMP Median ($/MWh) = 25.51
# LMP Mean ($/MWh) = 36.04
# Natural Gas Price ($/million BTU) = 8.21
# Bimodality Coefficient = 0.46
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# SPP_SOUTH_2019
# =========================================================================
# LMP Range ($/MWh) = (-43.7243, 1210.5837)
# LMP Median ($/MWh) = 18.47
# LMP Mean ($/MWh) = 21.48
# Natural Gas Price ($/million BTU) = 2.83
# Bimodality Coefficient = 0.56
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# SPP_SOUTH_2022
# =========================================================================
# LMP Range ($/MWh) = (-38.083, 871.8031)
# LMP Median ($/MWh) = 40.06
# LMP Mean ($/MWh) = 52.79
# Natural Gas Price ($/million BTU) = 7.61
# Bimodality Coefficient = 0.49
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$100_CAISO_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 178.28)
# LMP Median ($/MWh) = 73.59
# LMP Mean ($/MWh) = 52.97
# Natural Gas Price ($/million BTU) = 2.26
# Bimodality Coefficient = -0.66
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$150_CAISO_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 203.01)
# LMP Median ($/MWh) = 1.53
# LMP Mean ($/MWh) = 45.35
# Natural Gas Price ($/million BTU) = 2.26
# Bimodality Coefficient = -0.73
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$100_ERCOT_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 186.42)
# LMP Median ($/MWh) = 30.38
# LMP Mean ($/MWh) = 33.66
# Natural Gas Price ($/million BTU) = 2.64
# Bimodality Coefficient = -1.31
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$150_ERCOT_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 204.49)
# LMP Median ($/MWh) = 0.18
# LMP Mean ($/MWh) = 36.18
# Natural Gas Price ($/million BTU) = 2.64
# Bimodality Coefficient = -1.09
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$100_MISO-W_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 145.07)
# LMP Median ($/MWh) = 42.12
# LMP Mean ($/MWh) = 35.12
# Natural Gas Price ($/million BTU) = 1.69
# Bimodality Coefficient = -0.60
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$150_MISO-W_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 162.06)
# LMP Median ($/MWh) = 0.25
# LMP Mean ($/MWh) = 28.13
# Natural Gas Price ($/million BTU) = 2.01
# Bimodality Coefficient = -2.00
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$100_NYISO_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 182.14)
# LMP Median ($/MWh) = 1.41
# LMP Mean ($/MWh) = 35.22
# Natural Gas Price ($/million BTU) = 1.12
# Bimodality Coefficient = -1.04
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$150_NYISO_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 229.17)
# LMP Median ($/MWh) = 0.27
# LMP Mean ($/MWh) = 33.67
# Natural Gas Price ($/million BTU) = 1.14
# Bimodality Coefficient = -2.21
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$100_PJM-W_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 172.29)
# LMP Median ($/MWh) = 63.58
# LMP Mean ($/MWh) = 48.01
# Natural Gas Price ($/million BTU) = 1.42
# Bimodality Coefficient = -0.78
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# MiNg_$150_PJM-W_2035
# =========================================================================
# LMP Range ($/MWh) = (0.0, 181.06)
# LMP Median ($/MWh) = 47.84
# LMP Mean ($/MWh) = 49.81
# Natural Gas Price ($/million BTU) = 1.43
# Bimodality Coefficient = -0.58
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# BaseCase_2030
# =========================================================================
# LMP Range ($/MWh) = (-113.2815717, 1349.591575)
# LMP Median ($/MWh) = 24.13
# LMP Mean ($/MWh) = 30.25
# Natural Gas Price ($/million BTU) = 2.94
# Bimodality Coefficient = 0.97
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# HighWind_2030
# =========================================================================
# LMP Range ($/MWh) = (-113.2815693, 1349.591576)
# LMP Median ($/MWh) = 24.13
# LMP Mean ($/MWh) = 30.25
# Natural Gas Price ($/million BTU) = 2.94
# Bimodality Coefficient = 0.97
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# HighSolar_2030
# =========================================================================
# LMP Range ($/MWh) = (-111.2865714, 1800.0)
# LMP Median ($/MWh) = 22.77
# LMP Mean ($/MWh) = 30.13
# Natural Gas Price ($/million BTU) = 2.94
# Bimodality Coefficient = 0.91
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# WinterNY_2030
# =========================================================================
# LMP Range ($/MWh) = (2.6e-07, 4257.425614)
# LMP Median ($/MWh) = 23.73
# LMP Mean ($/MWh) = 29.09
# Natural Gas Price ($/million BTU) = 2.94
# Bimodality Coefficient = 0.82
#
# H2 Price ($/kg) = 2.0
# =========================================================================
# BaseCaseTax_2030
# =========================================================================
# LMP Range ($/MWh) = (-1.02e-07, 1800.000025)
# LMP Median ($/MWh) = 43.40
# LMP Mean ($/MWh) = 47.69
# Natural Gas Price ($/million BTU) = 2.94
# Bimodality Coefficient = 0.86
#
# H2 Price ($/kg) = 2.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/ipykernel_92592/2512050731.py in <cell line: 11>()
#      40         for model in models:
#      41             result_file = os.path.join(result_dir, f"{data_set}_{model}.csv")
# ---> 42             df = pd.read_csv(result_file)
#      43             n = len(df["profit ($/hr)"])
#      44             profit = (sum(df["profit ($/hr)"]) - sum(df["start_cost"]) - sum(df["stop_cost"]))/n*365*24/1e6
#
# ~/miniconda3/envs/idaes/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/idaes/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/miniconda3/envs/idaes/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/miniconda3/envs/idaes/lib/python3.10/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/miniconda3/envs/idaes/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/miniconda3/envs/idaes/lib/python3.10/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../market_results_20/BaseCaseTax_2030_model0.csv'

# %%
x_vec = np.linspace(-100, 300, 1000)
for data_set in data.metadata:
    print(data_set)
    gobj = scipy.stats.gaussian_kde(data.data[data_set].dropna())
    lmp_hist(data.data[data_set], range=(-100, 300))
    plt.plot(x_vec, gobj.pdf(x_vec))
    plt.show()
# Out:
# CAISO_NP15_2019
# CAISO_NP15_2022
# CAISO_ZP26_2019
# CAISO_ZP26_2022
# CAISO_SP15_2019
# CAISO_SP15_2022
# ERCOT_NORTH_2019
# ERCOT_NORTH_2022
# ERCOT_SOUTH_2019
# ERCOT_SOUTH_2022
# ERCOT_WEST_2019
# ERCOT_WEST_2022
# ERCOT_HOUSTON_2019
# ERCOT_HOUSTON_2022
# ISO_NE_2019
# ISO_NE_2022
# NYISO_2019
# NYISO_2022
# MYSO_INDIANA_2019
# MYSO_INDIANA_2022
# MYSO_LOUISIANA_2019
# MYSO_LOUISIANA_2022
# MYSO_MINNESOTA_2019
# MYSO_MINNESOTA_2022
# PJM_WEST_2019
# PJM_WEST_2022
# SPP_NORTH_2019
# SPP_NORTH_2022
# SPP_SOUTH_2019
# SPP_SOUTH_2022
# MiNg_$100_CAISO_2035
# MiNg_$150_CAISO_2035
# MiNg_$100_ERCOT_2035
# MiNg_$150_ERCOT_2035
# MiNg_$100_MISO-W_2035
# MiNg_$150_MISO-W_2035
# MiNg_$100_NYISO_2035
# MiNg_$150_NYISO_2035
# MiNg_$100_PJM-W_2035
# MiNg_$150_PJM-W_2035
# BaseCase_2030
# HighWind_2030
# HighSolar_2030
# WinterNY_2030
# BaseCaseTax_2030
# HighWindTax_2030
# HighSolarTax_2030
# WinterNYTax_2030
# BaseCaseCapRes_2030
# HighWindCapRes_2030
# HighSolarCapRes_2030
# WinterNYCapRes_2030
# BaseCaseTaxCapRes_2030
# HighWindTaxCapRes_2030
# HighSolarTaxCapRes_2030
# WinterNYTaxCapRes_2030
# ERCOT_0
# ERCOT_100
# CAISO_100
