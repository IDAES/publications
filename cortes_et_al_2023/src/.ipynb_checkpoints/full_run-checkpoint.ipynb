# %% [markdown]
# # Full Market Problem

# %% [markdown]
# ## Boiler Plate

# %%
import os
import time
import datetime
from util.surrogate import SurrogateProcessModels
from util.data import get_model_data, DataObject
from util.solve import (
    write_result_csv,
    print_simple_model_summary,
    print_summary,
    dicopt_solve,
)
from pyomo.opt import SolverStatus, TerminationCondition
import pyomo.environ as pyo
import numpy as np

# %% [markdown]
# ## Generate Surrogate Models and Read Data

# %%
surrogate = SurrogateProcessModels()
surrogate.generate_surrogate_models()
data = DataObject()
model_data = get_model_data()
h2_price = 2.0
groups = ["historical", "nrel", "o3", "princeton", "netl"]
out_path=f"../market_results_{int(h2_price*10)}"

# %% [markdown]
# ## Loop through and run models

# %%
tee = False


for data_set in data.metadata:
    if data.metadata[data_set]["group"] not in groups:
        continue
    for model in ["model0", "model1", "model3", "model4", "model5", "model6"]:
        if os.path.exists(os.path.join(out_path, f"{data_set}_{model}.csv")):
            continue
        print("")
        print("")
        print("=========================================================================")
        print(model)
        print(data_set)
        print("=========================================================================")
        m = surrogate.full_model(model, data_set=data_set, h2_price=h2_price)
        m.obj.deactivate()
        m.obj_bilin.activate()
        if hasattr(m, "pblk"):
            m.p_M1.deactivate()
            m.p_M2.deactivate()
            m.p_M3.deactivate()
            m.p_M4.deactivate()
        if hasattr(m, "hblk"):
            m.h_M1.deactivate()
            m.h_M2.deactivate()
            m.h_M3.deactivate()
            m.h_M4.deactivate()  
        print(datetime.datetime.now())
        start_time = time.time()
        res = dicopt_solve(m, tee=tee)
        stop_time = time.time()
        etime1_min = (stop_time-start_time)/60.0

        print("bilinear problem as NLP for initialization")
        if hasattr(m, "pblk"):
            for i in m.pblk:
                m.mp_profit[i] = m.pblk[i].profit_no_fixed*m.bin_power[i]
                m.p_M1.activate()
                #m.p_M2.activate()
                m.p_M3.activate()
                #m.p_M4.activate()
        if hasattr(m, "hblk"):
            for i in m.hblk:
                m.mh_profit[i] = m.hblk[i].profit_no_fixed*m.bin_hydrogen[i]
                m.h_M1.activate()
                #m.h_M2.activate()
                m.h_M3.activate()
                #m.h_M4.activate()   
        print_simple_model_summary(m)
        print(res.solver.termination_condition)
        
        end_it = False
        for c in m.component_data_objects(pyo.Constraint):
            try:
                e1 = c.body() - c.ub
            except TypeError:
                e1 = 0
            try:
                e2 = c.lb -  c.body()
            except TypeError:
                e2 = 0         
                
            err = max(e1, e2)
            if err > 1e-4:
                print(f"{c}: {err}")
                i = c.index()
                end_it = True
                
        if end_it:
            raise Exception(
                "Initialization violates big-M constraints, probably interpolation "
                " of max or min profit wasn't good enough.  You have a couple options "
                " sample more electricity prices, or pad M some more."
            )
        
        m.obj.activate()
        m.obj_bilin.deactivate()
        print(datetime.datetime.now())
        start_time = time.time()
        res = dicopt_solve(m, tee=tee)
        stop_time = time.time()
        etime2_min = (stop_time-start_time)/60.0
        etime_min = etime1_min + etime2_min
        print("")
        print(f"elapsed time: {etime_min} min")
        print("\nbig M")
        print_simple_model_summary(m)
        print(res.solver.termination_condition)
        print("\nResult")
        print(datetime.datetime.now())
        assert res.solver.status == SolverStatus.ok
        assert res.solver.termination_condition in [TerminationCondition.optimal, TerminationCondition.locallyOptimal]
        df = write_result_csv(m, model, data_set, path=out_path)
        print_summary(df, model, data_set)
        with open(os.path.join(out_path, "00_time.csv"), "a") as f:
            f.write(f"{model}, {data_set}, {etime1_min}, {etime2_min}, {etime_min}, {res.solver.termination_condition}\n")
# Out:
# =========================================================================
# model0
# NETL_ERCOT_GEN_25
# =========================================================================
# 2023-03-12 12:40:54.048870
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 37.3538579805895
# Time in power mode = 66.42%
# Time in off mode = 33.58%
# locallyOptimal
# 2023-03-12 12:41:53.385356
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 0.6074939330418905 min
#
# big M
# Objective = 37.3538579805895
# Time in power mode = 66.42%
# Time in off mode = 33.58%
# optimal
#
# Result
# 2023-03-12 12:42:22.372581
# Model: model0
# LMP Data: NETL_ERCOT_GEN_25
# Annual Profit = -139.8180204090066 Million $/yr)
# Annual Power = 3.7816999999999994 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 66.41552511415524%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 33.58447488584475%
#
#
# =========================================================================
# model1
# NETL_ERCOT_GEN_25
# =========================================================================
# 2023-03-12 12:43:45.878560
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 109.4965028644966
# Time in power mode = 98.22%
# Time in off mode = 1.78%
# locallyOptimal
# 2023-03-12 12:44:43.888418
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 2.006776750087738 min
#
# big M
# Objective = 109.85081169441122
# Time in power mode = 100.00%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 12:46:38.513504
# Model: model1
# LMP Data: NETL_ERCOT_GEN_25
# Annual Profit = -23.670688955695677 Million $/yr)
# Annual Power = 5.548042104149626 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 100.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model3
# NETL_ERCOT_GEN_25
# =========================================================================
# 2023-03-12 12:49:22.223281
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 97.74806426948977
# Time in hydrogen mode = 72.08%
# Time in power mode = 27.92%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 12:51:43.625512
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 8.547957150141398 min
#
# big M
# Objective = 101.1118793066351
# Time in hydrogen mode = 87.05%
# Time in power mode = 12.95%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 12:59:39.574799
# Model: model3
# LMP Data: NETL_ERCOT_GEN_25
# Annual Profit = -132.86599372738797 Million $/yr)
# Annual Power = 0.41245308222557847 Million MWh
# Annual Hydrogen = 134.82219239748355 Million kg
# Time power only = 12.945205479452055%
# Time hydrogen/power = 87.05479452054794%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model4
# NETL_ERCOT_GEN_25
# =========================================================================
# 2023-03-12 13:02:24.334670
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 127.798453157237
# Time in hydrogen mode = 9.92%
# Time in power mode = 90.08%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 13:04:18.853847
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 3.2667168617248534 min
#
# big M
# Objective = 139.57113627149556
# Time in hydrogen mode = 32.80%
# Time in power mode = 67.20%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 13:07:24.306287
# Model: model4
# LMP Data: NETL_ERCOT_GEN_25
# Annual Profit = -3.075684626170338 Million $/yr)
# Annual Power = 1.9314090972882085 Million MWh
# Annual Hydrogen = 51.714000000000006 Million kg
# Time power only = 67.20319634703196%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 32.79680365296804%
# Time off = 0.0%
#
#
# =========================================================================
# model5
# NETL_ERCOT_GEN_25
# =========================================================================
# 2023-03-12 13:10:14.767613
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 169.63282346234178
# Time in hydrogen mode = 35.25%
# Time in power mode = 64.75%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 13:12:43.020651
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 9.977916717529297 min
#
# big M
# Objective = 195.90388597683835
# Time in hydrogen mode = 85.32%
# Time in power mode = 14.68%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 13:21:57.571550
# Model: model5
# LMP Data: NETL_ERCOT_GEN_25
# Annual Profit = 23.721804115710505 Million $/yr)
# Annual Power = 0.8824386260748067 Million MWh
# Annual Hydrogen = 133.84282725835655 Million kg
# Time power only = 14.680365296803652%
# Time hydrogen/power = 85.31963470319634%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model6
# NETL_ERCOT_GEN_25
# =========================================================================
# 2023-03-12 13:23:26.124101
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 73.07571608007821
# Time in hydrogen mode = 92.41%
# Time in off mode = 7.59%
# locallyOptimal
# 2023-03-12 13:24:28.047895
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.551513417561849 min
#
# big M
# Objective = 73.21359811394892
# Time in hydrogen mode = 94.33%
# Time in off mode = 5.67%
# optimal
#
# Result
# 2023-03-12 13:25:51.555986
# Model: model6
# LMP Data: NETL_ERCOT_GEN_25
# Annual Profit = -3.0248880521807244 Million $/yr)
# Annual Power = -5.352885663374809 Million MWh
# Annual Hydrogen = 133.9596 Million kg
# Time power only = 0.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 94.32648401826485%
# Time off = 5.67351598173516%
#
#
# =========================================================================
# model0
# NETL_ERCOT_GEN_50
# =========================================================================
# 2023-03-12 13:27:17.656488
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 84.1687379671324
# Time in power mode = 81.67%
# Time in off mode = 18.33%
# locallyOptimal
# 2023-03-12 13:28:15.747184
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 0.5061776240666707 min
#
# big M
# Objective = 84.16873796713243
# Time in power mode = 81.67%
# Time in off mode = 18.33%
# optimal
#
# Result
# 2023-03-12 13:28:40.879678
# Model: model0
# LMP Data: NETL_ERCOT_GEN_50
# Annual Profit = -98.80818554079369 Million $/yr)
# Annual Power = 4.6501 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 81.66666666666667%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 18.333333333333332%
#
#
# =========================================================================
# model1
# NETL_ERCOT_GEN_50
# =========================================================================
# 2023-03-12 13:30:07.320569
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 159.9494237674647
# Time in power mode = 99.50%
# Time in off mode = 0.50%
# locallyOptimal
# 2023-03-12 13:31:06.724576
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.483539084593455 min
#
# big M
# Objective = 160.14566924317919
# Time in power mode = 100.00%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 13:32:29.560137
# Model: model1
# LMP Data: NETL_ERCOT_GEN_50
# Annual Profit = 20.387606257024757 Million $/yr)
# Annual Power = 5.572364233880336 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 100.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model3
# NETL_ERCOT_GEN_50
# =========================================================================
# 2023-03-12 13:35:19.162132
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 114.08725994315913
# Time in hydrogen mode = 35.31%
# Time in power mode = 64.69%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 13:37:27.366013
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 9.7934379140536 min
#
# big M
# Objective = 117.33756617078626
# Time in hydrogen mode = 56.80%
# Time in power mode = 43.20%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 13:46:51.536973
# Model: model3
# LMP Data: NETL_ERCOT_GEN_50
# Annual Profit = -118.65229203439159 Million $/yr)
# Annual Power = 2.4280888158476137 Million MWh
# Annual Hydrogen = 83.37051966628258 Million kg
# Time power only = 43.19634703196347%
# Time hydrogen/power = 56.80365296803653%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model4
# NETL_ERCOT_GEN_50
# =========================================================================
# 2023-03-12 13:49:36.273120
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 175.7034075258714
# Time in hydrogen mode = 8.47%
# Time in power mode = 91.53%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 13:51:35.448640
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.6693031469980875 min
#
# big M
# Objective = 183.34511956077336
# Time in hydrogen mode = 18.24%
# Time in power mode = 81.76%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 13:53:01.116345
# Model: model4
# LMP Data: NETL_ERCOT_GEN_50
# Annual Profit = 35.270324735237594 Million $/yr)
# Annual Power = 3.6011979594385455 Million MWh
# Annual Hydrogen = 28.764000000000003 Million kg
# Time power only = 81.7579908675799%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 18.242009132420094%
# Time off = 0.0%
#
#
# =========================================================================
# model5
# NETL_ERCOT_GEN_50
# =========================================================================
# 2023-03-12 13:55:51.399692
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 205.4893997421842
# Time in hydrogen mode = 18.60%
# Time in power mode = 81.40%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 13:58:04.995546
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 9.590489383538564 min
#
# big M
# Objective = 217.77182977571204
# Time in hydrogen mode = 51.97%
# Time in power mode = 48.03%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 14:07:11.834504
# Model: model5
# LMP Data: NETL_ERCOT_GEN_50
# Annual Profit = 42.87812288352279 Million $/yr)
# Annual Power = 3.133222881601272 Million MWh
# Annual Hydrogen = 77.02224266141701 Million kg
# Time power only = 48.02511415525114%
# Time hydrogen/power = 51.97488584474886%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model6
# NETL_ERCOT_GEN_50
# =========================================================================
# 2023-03-12 14:08:40.967819
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 35.61807836943493
# Time in hydrogen mode = 64.99%
# Time in off mode = 35.01%
# locallyOptimal
# 2023-03-12 14:09:46.237757
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.9623208363850912 min
#
# big M
# Objective = 37.56421241475517
# Time in hydrogen mode = 83.32%
# Time in off mode = 16.68%
# optimal
#
# Result
# 2023-03-12 14:11:30.734313
# Model: model6
# LMP Data: NETL_ERCOT_GEN_50
# Annual Profit = -34.25374992467467 Million $/yr)
# Annual Power = -3.3114978806986395 Million MWh
# Annual Hydrogen = 83.1996 Million kg
# Time power only = 0.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 83.32191780821918%
# Time off = 16.67808219178082%
#
#
# =========================================================================
# model0
# NETL_ERCOT_GEN_100
# =========================================================================
# 2023-03-12 14:12:58.388670
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 185.2898141281412
# Time in power mode = 87.64%
# Time in off mode = 12.36%
# locallyOptimal
# 2023-03-12 14:13:54.671186
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 0.5875493367513022 min
#
# big M
# Objective = 185.28981412814122
# Time in power mode = 87.64%
# Time in off mode = 12.36%
# optimal
#
# Result
# 2023-03-12 14:14:25.541331
# Model: model0
# LMP Data: NETL_ERCOT_GEN_100
# Annual Profit = -10.226122823748284 Million $/yr)
# Annual Power = 4.99005 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 87.63698630136987%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 12.363013698630137%
#
#
# =========================================================================
# model1
# NETL_ERCOT_GEN_100
# =========================================================================
# 2023-03-12 14:15:51.814809
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 263.18621450744695
# Time in power mode = 99.50%
# Time in off mode = 0.50%
# locallyOptimal
# 2023-03-12 14:16:51.966550
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.2850685477256776 min
#
# big M
# Objective = 263.4077097438009
# Time in power mode = 100.00%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 14:18:02.568498
# Model: model1
# LMP Data: NETL_ERCOT_GEN_100
# Annual Profit = 110.84515373556924 Million $/yr)
# Annual Power = 5.577458017483847 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 100.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model3
# NETL_ERCOT_GEN_100
# =========================================================================
# 2023-03-12 14:20:50.446741
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 200.5712216564237
# Time in hydrogen mode = 15.88%
# Time in power mode = 84.12%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 14:22:52.819950
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 7.339494597911835 min
#
# big M
# Objective = 201.77593399668515
# Time in hydrogen mode = 21.87%
# Time in power mode = 78.13%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 14:29:56.448191
# Model: model3
# LMP Data: NETL_ERCOT_GEN_100
# Annual Profit = -44.68428181890398 Million $/yr)
# Annual Power = 4.381369069656537 Million MWh
# Annual Hydrogen = 33.499063289435725 Million kg
# Time power only = 78.12785388127854%
# Time hydrogen/power = 21.87214611872146%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model4
# NETL_ERCOT_GEN_100
# =========================================================================
# 2023-03-12 14:32:42.511749
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 277.8607093018376
# Time in hydrogen mode = 7.67%
# Time in power mode = 92.33%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 14:34:47.016853
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.6861205697059631 min
#
# big M
# Objective = 281.7507207204715
# Time in hydrogen mode = 12.34%
# Time in power mode = 87.66%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 14:36:10.549725
# Model: model4
# LMP Data: NETL_ERCOT_GEN_100
# Annual Profit = 121.4736313511334 Million $/yr)
# Annual Power = 4.27828097256136 Million MWh
# Annual Hydrogen = 19.458000000000002 Million kg
# Time power only = 87.65981735159816%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 12.340182648401827%
# Time off = 0.0%
#
#
# =========================================================================
# model5
# NETL_ERCOT_GEN_100
# =========================================================================
# 2023-03-12 14:39:02.534117
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 310.14774920057516
# Time in hydrogen mode = 12.43%
# Time in power mode = 87.57%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 14:41:05.823343
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 5.902200750509898 min
#
# big M
# Objective = 313.13931879859734
# Time in hydrogen mode = 22.37%
# Time in power mode = 77.63%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 14:46:41.789574
# Model: model5
# LMP Data: NETL_ERCOT_GEN_100
# Annual Profit = 126.42004326757171 Million $/yr)
# Annual Power = 4.8765114565035885 Million MWh
# Annual Hydrogen = 32.872474363990015 Million kg
# Time power only = 77.6255707762557%
# Time hydrogen/power = 22.37442922374429%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model6
# NETL_ERCOT_GEN_100
# =========================================================================
# 2023-03-12 14:48:11.991737
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 13.928430529042705
# Time in hydrogen mode = 19.90%
# Time in off mode = 80.10%
# locallyOptimal
# 2023-03-12 14:49:20.890573
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 2.134624226888021 min
#
# big M
# Objective = 18.819980758838025
# Time in hydrogen mode = 33.94%
# Time in off mode = 66.06%
# optimal
#
# Result
# 2023-03-12 14:51:12.790749
# Model: model6
# LMP Data: NETL_ERCOT_GEN_100
# Annual Profit = -50.67369685525598 Million $/yr)
# Annual Power = -1.3133295975252852 Million MWh
# Annual Hydrogen = 33.0084 Million kg
# Time power only = 0.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 33.938356164383556%
# Time off = 66.06164383561644%
#
#
# =========================================================================
# model0
# NETL_ERCOT_GEN_250
# =========================================================================
# 2023-03-12 14:52:43.775167
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 490.1850933292927
# Time in power mode = 87.64%
# Time in off mode = 12.36%
# locallyOptimal
# 2023-03-12 14:53:40.717851
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 0.3553423364957174 min
#
# big M
# Objective = 490.18509332930137
# Time in power mode = 87.64%
# Time in off mode = 12.36%
# optimal
#
# Result
# 2023-03-12 14:53:57.396353
# Model: model0
# LMP Data: NETL_ERCOT_GEN_250
# Annual Profit = 256.8621417564686 Million $/yr)
# Annual Power = 4.99005 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 87.63698630136987%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 12.363013698630137%
#
#
# =========================================================================
# model1
# NETL_ERCOT_GEN_250
# =========================================================================
# 2023-03-12 14:55:25.624797
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 568.1015058506285
# Time in power mode = 99.59%
# Time in off mode = 0.41%
# locallyOptimal
# 2023-03-12 14:56:23.759507
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 0.5518703858057658 min
#
# big M
# Objective = 568.3231078440136
# Time in power mode = 100.00%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 14:56:51.218384
# Model: model1
# LMP Data: NETL_ERCOT_GEN_250
# Annual Profit = 377.9510424713561 Million $/yr)
# Annual Power = 5.580408555889302 Million MWh
# Annual Hydrogen = 0.0 Million kg
# Time power only = 100.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model3
# NETL_ERCOT_GEN_250
# =========================================================================
# 2023-03-12 14:59:42.138270
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 505.11528256541027
# Time in hydrogen mode = 15.35%
# Time in power mode = 84.65%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 15:01:43.504723
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 7.2873626788457235 min
#
# big M
# Objective = 505.69633006397805
# Time in hydrogen mode = 18.24%
# Time in power mode = 81.76%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 15:08:43.900439
# Model: model3
# LMP Data: NETL_ERCOT_GEN_250
# Annual Profit = 221.54998513604298 Million $/yr)
# Annual Power = 4.5972803544663545 Million MWh
# Annual Hydrogen = 27.987051541190834 Million kg
# Time power only = 81.7579908675799%
# Time hydrogen/power = 18.242009132420094%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model4
# NETL_ERCOT_GEN_250
# =========================================================================
# 2023-03-12 15:11:30.967352
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 582.2685675254704
# Time in hydrogen mode = 7.50%
# Time in power mode = 92.50%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 15:13:42.241387
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 2.006253186861674 min
#
# big M
# Objective = 586.3918257530569
# Time in hydrogen mode = 12.37%
# Time in power mode = 87.63%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 15:15:15.356027
# Model: model4
# LMP Data: NETL_ERCOT_GEN_250
# Annual Profit = 388.33923935967755 Million $/yr)
# Annual Power = 4.274352057591595 Million MWh
# Annual Hydrogen = 19.512 Million kg
# Time power only = 87.62557077625571%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 12.374429223744292%
# Time off = 0.0%
#
#
# =========================================================================
# model5
# NETL_ERCOT_GEN_250
# =========================================================================
# 2023-03-12 15:18:09.530973
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 644.053950105699
# Time in hydrogen mode = 12.40%
# Time in power mode = 87.60%
# Time in off mode = 0.00%
# locallyOptimal
# 2023-03-12 15:20:12.394119
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 5.0694687525431315 min
#
# big M
# Objective = 646.239329532119
# Time in hydrogen mode = 17.89%
# Time in power mode = 82.11%
# Time in off mode = 0.00%
# optimal
#
# Result
# 2023-03-12 15:24:58.805275
# Model: model5
# LMP Data: NETL_ERCOT_GEN_250
# Annual Profit = 418.2156526701349 Million $/yr)
# Annual Power = 5.075178881110564 Million MWh
# Annual Hydrogen = 27.905059295498752 Million kg
# Time power only = 82.11187214611873%
# Time hydrogen/power = 17.88812785388128%
# Time hydrogen only = 0.0%
# Time off = 0.0%
#
#
# =========================================================================
# model6
# NETL_ERCOT_GEN_250
# =========================================================================
# 2023-03-12 15:26:29.120417
#
# GAMS WORKING DIRECTORY: temp
#
# bilinear problem as NLP for initialization
# Objective = 6.264242052734438
# Time in hydrogen mode = 4.34%
# Time in off mode = 95.66%
# locallyOptimal
# 2023-03-12 15:28:10.397377
#
# GAMS WORKING DIRECTORY: temp
#
#
# elapsed time: 1.504298766454061 min
#
# big M
# Objective = 12.593363089794808
# Time in hydrogen mode = 16.51%
# Time in off mode = 83.49%
# optimal
#
# Result
# 2023-03-12 15:28:51.714075
# Model: model6
# LMP Data: NETL_ERCOT_GEN_250
# Annual Profit = -56.12821393333557 Million $/yr)
# Annual Power = -0.8336799466645096 Million MWh
# Annual Hydrogen = 20.8872 Million kg
# Time power only = 0.0%
# Time hydrogen/power = 0.0%
# Time hydrogen only = 16.506849315068493%
# Time off = 83.4931506849315%

# %%
for c in m.h_M1.values():
    try:
        e1 = c.body() - c.ub
    except TypeError:
        e1 = 0
    try:
        e2 = c.lb -  c.body()
    except TypeError:
        e2 = 0         

    err = max(e1, e2)
    if err > 1e-5:
        i = c.index()
        print(f"{c}: {err}, Mhi = {pyo.value(m.Mh_hi[i])}, Mlo = {pyo.value(m.Mh_lo[i])}")
